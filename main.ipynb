# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import mne
import os

path = os.path.join(os.getcwd(), 'subjects')

ec = os.path.join(path,'C:/Users/hp/OneDrive/Desktop/mini/sub-19681349_ses-1_task-restEC_eeg.vhdr')
nc = os.path.join(path,'C:/Users/hp/OneDrive/Desktop/mini/sub-19681349_ses-1_task-restEC_eeg.vhdr')
ec_raw = mne.io.read_raw_brainvision(ec, preload=True)
nc_raw = mne.io.read_raw_brainvision(nc, preload=True) 

# Set channels

picks = list(set(ec_raw.ch_names) - {'Mass', 'OrbOcc', 'Erbs', 'HNHR', 'HPHL', 'VNVB', 'VPVA'})
ec_raw.pick_channels(picks)
nc_raw.pick_channels(picks)


# To check heart beat artifacts

# ecg_epochs = mne.preprocessing.create_ecg_epochs(nc_raw, ch_name='Erbs', picks=picks)
# ecg_epochs.plot_image(combine='mean')
# Out:
# Extracting parameters from C:/Users/hp/OneDrive/Desktop/mini/sub-19681349_ses-1_task-restEC_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 60002  =      0.000 ...   120.004 secs...
# Extracting parameters from C:/Users/hp/OneDrive/Desktop/mini/sub-19681349_ses-1_task-restEC_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 60002  =      0.000 ...   120.004 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# <RawBrainVision | sub-19681349_ses-1_task-restEC_eeg.eeg, 26 x 60003 (120.0 s), ~11.9 MB, data loaded>

# %%
# Set montage

ten_twenty_montage = mne.channels.make_standard_montage('standard_1020')

ec_raw.set_montage(ten_twenty_montage)
nc_raw.set_montage(ten_twenty_montage)

fig = ten_twenty_montage.plot(kind='3d')
fig.gca().view_init(azim=70, elev=15)  # set view angle
ten_twenty_montage.plot(kind='topomap', show_names=False)
# Out:
# 4 duplicate electrode labels found:
# T7/T3, T8/T4, P7/T5, P8/T6
# Plotting 90 unique labels.
# 4 duplicate electrode labels found:
# T7/T3, T8/T4, P7/T5, P8/T6
# Plotting 90 unique labels.

# %%
# Artifact removal -- Eyes open

ica = mne.preprocessing.ICA(n_components=15, max_iter='auto', random_state=42)

nc_filt = nc_raw.copy().filter(l_freq=1., h_freq=None)
ica.fit(nc_filt)

ica.plot_components() 
ica.plot_overlay(nc_filt, start=0., stop=10., exclude=[0], picks=['Fp1']) # Selecting first component

ica.exclude = [0]
ica.apply(nc_raw)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 1651 samples (3.302 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    0.0s finished
# Fitting ICA to data using 26 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.6s.
# <MNEFigure size 975x731.5 with 15 Axes>
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 26 PCA components
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 26 PCA components
# <RawBrainVision | sub-19681349_ses-1_task-restEC_eeg.eeg, 26 x 60003 (120.0 s), ~11.9 MB, data loaded>

# %%
# Filtering
ec_raw.filter(l_freq=.5, h_freq=None, verbose=0)
nc_raw.filter(l_freq=.5, h_freq=None, verbose=0);
#metadata

ec_raw.info, nc_raw.info
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    0.0s finished
# (<Info | 8 non-empty values
#   bads: []
#   ch_names: Fp1, Fp2, F7, F3, Fz, F4, F8, FC3, FCz, FC4, T7, C3, Cz, C4, T8, ...
#   chs: 26 EEG
#   custom_ref_applied: False
#   dig: 29 items (3 Cardinal, 26 EEG)
#   highpass: 0.5 Hz
#   lowpass: 250.0 Hz
#   meas_date: unspecified
#   nchan: 26
#   projs: []
#   sfreq: 500.0 Hz
#  >,
#  <Info | 8 non-empty values
#   bads: []
#   ch_names: Fp1, Fp2, F7, F3, Fz, F4, F8, FC3, FCz, FC4, T7, C3, Cz, C4, T8, ...
#   chs: 26 EEG
#   custom_ref_applied: False
#   dig: 29 items (3 Cardinal, 26 EEG)
#   highpass: 0.5 Hz
#   lowpass: 250.0 Hz
#   meas_date: unspecified
#   nchan: 26
#   projs: []
#   sfreq: 500.0 Hz
#  >)

# %%
pip install mne-qt-browser
# Out:
# Requirement already satisfied: mne-qt-browser in c:\users\hp\anaconda3\lib\site-packages (0.6.1)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from mne-qt-browser) (23.0)
# Requirement already satisfied: setuptools>=65 in c:\users\hp\anaconda3\lib\site-packages (from mne-qt-browser) (68.0.0)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from mne-qt-browser) (1.24.3)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from mne-qt-browser) (1.10.1)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (from mne-qt-browser) (3.7.1)
# Requirement already satisfied: qtpy in c:\users\hp\anaconda3\lib\site-packages (from mne-qt-browser) (2.2.0)
# Requirement already satisfied: scooby in c:\users\hp\anaconda3\lib\site-packages (from mne-qt-browser) (0.9.2)
# Requirement already satisfied: mne>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from mne-qt-browser) (1.6.0)
# Requirement already satisfied: pyqtgraph>=0.12.3 in c:\users\hp\anaconda3\lib\site-packages (from mne-qt-browser) (0.13.3)
# Requirement already satisfied: colorspacious in c:\users\hp\anaconda3\lib\site-packages (from mne-qt-browser) (1.1.2)
# Requirement already satisfied: darkdetect in c:\users\hp\anaconda3\lib\site-packages (from mne-qt-browser) (0.8.0)
# Requirement already satisfied: qdarkstyle in c:\users\hp\anaconda3\lib\site-packages (from mne-qt-browser) (3.0.2)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from mne>=1.0->mne-qt-browser) (4.65.0)
# Requirement already satisfied: pooch>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from mne>=1.0->mne-qt-browser) (1.8.0)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\lib\site-packages (from mne>=1.0->mne-qt-browser) (5.1.1)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from mne>=1.0->mne-qt-browser) (3.1.2)
# Requirement already satisfied: lazy-loader>=0.3 in c:\users\hp\anaconda3\lib\site-packages (from mne>=1.0->mne-qt-browser) (0.3)
# Requirement already satisfied: defusedxml in c:\users\hp\anaconda3\lib\site-packages (from mne>=1.0->mne-qt-browser) (0.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->mne-qt-browser) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->mne-qt-browser) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->mne-qt-browser) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->mne-qt-browser) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->mne-qt-browser) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->mne-qt-browser) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->mne-qt-browser) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\hp\anaconda3\lib\site-packages (from pooch>=1.5->mne>=1.0->mne-qt-browser) (2.5.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\hp\anaconda3\lib\site-packages (from pooch>=1.5->mne>=1.0->mne-qt-browser) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mne-qt-browser) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->mne>=1.0->mne-qt-browser) (2.1.1)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm->mne>=1.0->mne-qt-browser) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.0->mne-qt-browser) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.0->mne-qt-browser) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.0->mne-qt-browser) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.0->mne-qt-browser) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
with mne.viz.use_browser_backend('qt'):
    nc_raw.plot(highpass=.5, lowpass=50., filtorder=2)
# Out:
# Using qt as 2D backend.
# Setting up band-pass filter from 0.5 - 50 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoffs at 0.50, 50.00 Hz: -6.02, -6.02 dB

# %%
with mne.viz.use_browser_backend('qt'):
    ec_raw.plot(highpass=.5, lowpass=50., filtorder=2)
# Out:
# Setting up band-pass filter from 0.5 - 50 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoffs at 0.50, 50.00 Hz: -6.02, -6.02 dB

# %%
fig1 = nc_raw.plot_psd(fmax=250, average=True)
fig1.suptitle('Eyes open')
fig2 = ec_raw.plot_psd(fmax=250, average=True)
fig2.suptitle('Eyes closed')
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 4.096 (s)
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 4.096 (s)
# Text(0.5, 0.98, 'Eyes closed')
# <MNELineFigure size 1000x350 with 1 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
nc_raw.resample(100, verbose=0)
ec_raw.resample(100, verbose=0);

fig1 = nc_raw.plot_psd(average=True)
fig1.suptitle('Eyes open')

fig2 = ec_raw.plot_psd(average=True)
fig2.suptitle('Eyes open')
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 20.480 (s)
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 20.480 (s)
# Text(0.5, 0.98, 'Eyes open')
# <MNELineFigure size 1000x350 with 1 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
# Temporal topomap plots

data, times = ec_raw.get_data(return_times=True)
channel_indices_by_type = mne.io.pick.channel_indices_by_type(ec_raw.info)
len(channel_indices_by_type['eeg'])
info = mne.pick_info(ec_raw.info, channel_indices_by_type['eeg'])

import matplotlib

def plot_topomaps(data, info):
    _, nsamps = data.shape
    fig = matplotlib.figure.Figure(figsize=(10,8))
    axs = fig.subplots(5,5)
    for row in range(5):
        for col in range(5):
            samp = int(nsamps*(row*5+col)/25)
            t = samp/info['sfreq']
            mne.viz.plot_topomap(data[:,samp], info, axes=axs[row,col], cmap='hot_r', show=False)
            axs[row,col].set_title('%ds'%(int(t)))
    return(fig)

plot_topomaps(data,info)

# %%
duration = 30.
bands = [(0, 4, 'Delta'), (4, 8, 'Theta'), (8, 12, 'Alpha'),
         (12, 30, 'Beta'), (30, 45, 'Gamma')]

nc_epoch = mne.make_fixed_length_epochs(nc_raw, duration=duration, preload=True)

nc_epoch.plot_psd_topomap(bands=bands,
            bandwidth=None, adaptive=False, low_bias=True, normalization='length', 
            ch_type=None, cmap='hot_r', agg_fun=None, dB=True, n_jobs=-1, 
            normalize=False, 
            cbar_fmt='auto', outlines='head', show=True);
# Out:
# Not setting metadata
# 4 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 4 events and 3000 original time points ...
# 0 bad epochs dropped
# NOTE: plot_psd_topomap() is a legacy function. New code should use .compute_psd().plot_topomap().
#     Using multitaper spectrum estimation with 7 DPSS windows
# converting legacy list-of-tuples input to a dict for the `bands` parameter

# %%
ec_epoch = mne.make_fixed_length_epochs(ec_raw, duration=duration, preload=True)

ec_epoch.plot_psd_topomap(bands=bands,
            bandwidth=None, adaptive=False, low_bias=True, normalization='length', 
            ch_type=None, cmap='hot_r', agg_fun=None, dB=True, n_jobs=-1, 
            normalize=False, 
            cbar_fmt='auto', outlines='head', show=True);
# Out:
# Not setting metadata
# 4 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 4 events and 3000 original time points ...
# 0 bad epochs dropped
# NOTE: plot_psd_topomap() is a legacy function. New code should use .compute_psd().plot_topomap().
#     Using multitaper spectrum estimation with 7 DPSS windows
# converting legacy list-of-tuples input to a dict for the `bands` parameter

# %%
# from mne.time_frequency import psd_welch
# alpha = (8, 12)
# fmin = 0
# fmax= 100
# average = 'mean'
# window = 'hamming'

# psd1, freq = mne.time_frequency.psd_welch(ec_raw,window=window, picks=picks,average=average, verbose=0)
# psd2, freq = mne.time_frequency.psd_welch(nc_raw,window=window, picks=picks,average=average, verbose=0)

# freq_idx = [np.argmin(np.abs(freq - frequency)) for frequency in alpha]
# freq_range = slice(freq_idx[0], freq_idx[1] + 1)

# psd_diff = psd2 - psd1
# psd_avg = psd_diff[:, freq_idx].mean(axis = 1)

# mne.viz.plot_topomap(psd_avg, info, cmap='hot_r', outlines='head', show=True)
from mne.time_frequency import psd_array_multitaper

alpha = (8, 12)
fmin = 0
fmax= 100
average = 'mean'
window = 'hamming'

# Assuming 'ec_raw' and 'nc_raw' are your Raw objects
psd1, freq = psd_array_multitaper(ec_raw.get_data(), ec_raw.info['sfreq'], fmin=fmin, fmax=fmax)
psd2, freq = psd_array_multitaper(nc_raw.get_data(), nc_raw.info['sfreq'], fmin=fmin, fmax=fmax)

freq_idx = [np.argmin(np.abs(freq - frequency)) for frequency in alpha]
freq_range = slice(freq_idx[0], freq_idx[1] + 1)

psd_diff = psd2 - psd1
psd_avg = psd_diff[:, freq_idx].mean(axis = 1)

mne.viz.plot_topomap(psd_avg, info, cmap='hot_r', outlines='head', show=True)
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
#     Using multitaper spectrum estimation with 7 DPSS windows
# (<matplotlib.image.AxesImage at 0x15be5022f90>,
#  <matplotlib.contour.QuadContourSet at 0x15be4f6a910>)
